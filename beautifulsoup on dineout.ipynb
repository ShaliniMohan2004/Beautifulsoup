# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get('https://www.dineout.co.in/jaipur-restaurants?city_name=jaipur&limit=21&start=0&cityId=10&listing=1&tag%5B%5D=Buffet&showAvailableTicket=0')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/><link href="/manifest.json" rel="manifest"/><style type="text/css">
#             @font-face {
#                 font-family: 'dineicon';
#                 src:  url('/fonts/dineicon.eot');
#                 src:  url('/fonts/dineicon.eot#iefix') format('embedded-opentype'),
#                 url('/fonts/dineicon.ttf') format('truetype'),
#                 url('/fonts/dineicon.woff') format('woff'),
#                 url('/fonts/dineicon.svg#dineicon') format('svg');
#                 font-weight: normal;
# 				font-style: normal;
# 				font-display: swap;
#             }
#             .hide {
#                 display: none !important;
#             }
#             .async-hide{
#                 opacity: inherit !important;
#             }
# ...

# %%
first_title = soup.find('div',class_="restnt-info cursor")
first_title
# Out:
# <div class="restnt-info cursor" data-gatype="RestaurantNameClick"><a analytics-action="RestaurantCardClick" analytics-label="51402_Flavours - Cafe Restaurant" class="restnt-name ellipsis" data-w-onclick="sendAnalyticsCommon|w1-restarant" href="/jaipur/flavours-cafe-restaurant-bani-park-central-jaipur-51402">Flavours - Cafe Restaurant</a><div class="restnt-loc ellipsis" data-w-onclick="stopClickPropagation|w1-restarant"><a href="/jaipur-restaurants/nirwana-hometel-landmark">Nirwana Hometel,</a><a data-name="Bani Park" data-type="LocalityClick" href="/jaipur-restaurants/central-jaipur/bani-park">Bani Park</a>, <a data-name="Central Jaipur" data-type="AreaClick" href="/jaipur-restaurants/central-jaipur">Central Jaipur</a></div></div>

# %%
first_title.text
# Out:
# 'Flavours - Cafe RestaurantNirwana Hometel,Bani Park, Central Jaipur'

# %%
loc = soup.find('div',class_="restnt-loc ellipsis")
loc
# Out:
# <div class="restnt-loc ellipsis" data-w-onclick="stopClickPropagation|w1-restarant"><a href="/jaipur-restaurants/nirwana-hometel-landmark">Nirwana Hometel,</a><a data-name="Bani Park" data-type="LocalityClick" href="/jaipur-restaurants/central-jaipur/bani-park">Bani Park</a>, <a data-name="Central Jaipur" data-type="AreaClick" href="/jaipur-restaurants/central-jaipur">Central Jaipur</a></div>

# %%
loc.text
# Out:
# 'Nirwana Hometel,Bani Park, Central Jaipur'

# %%
price=soup.find("span",class_="double-line-ellipsis")
price.text.split()
# Out:
# ['₹',
#  '1,200',
#  'for',
#  '2',
#  '(approx)',
#  '|',
#  'Chinese,',
#  'North',
#  'Indian,',
#  'Fast',
#  'Food']

# %%
price.text.replace('₹','')
# Out:
# ' 1,200 for 2 (approx) | Chinese, North Indian, Fast Food'

# %%
price.text.split()[1:2]
# Out:
# ['1,200']

# %%
titles =[]
for i in soup.find_all('div',class_="restnt-info cursor"):
    titles.append(i.text)
titles
# Out:
# ['Flavours - Cafe RestaurantNirwana Hometel,Bani Park, Central Jaipur',
#  'Rajasthani Thali Dal Baati ChurmaBani Park, Central Jaipur',
#  'OasisHotel Park Prime,C Scheme, Central Jaipur',
#  '\xa0Ten Twisters BarbequeC Scheme, Central Jaipur',
#  'MarigoldGolden Tulip,Mirza Ismail Road, West Jaipur',
#  'Republic Of NoodlesLemon Tree Premier Hotel,Bani Park, Central Jaipur',
#  'Citrus CafeLemon Tree Premier Hotel,Bani Park, Central Jaipur',
#  'BazaarZone by The Park,Bani Park, Central Jaipur',
#  'Fusion RestroLal Kothi, Central Jaipur',
#  'TGIB : The Grand Indian BuffetVaishali Nagar, West Jaipur',
#  'TribeRenest,Mansarovar, South Jaipur',
#  'Vintage JourneyAdarsh Nagar, East Jaipur',
#  'Clever Fox CafeRed Fox Hotel,Malviya Nagar, South Jaipur',
#  'Blue CorianderLords Plaza,Tonk Road, South Jaipur',
#  'The Barbeque CompanyMalviya Nagar, South Jaipur',
#  'TVG - The Vegetarian GrillMalviya Nagar, South Jaipur',
#  'DurbarHotel Clarks Amer,Malviya Nagar, South Jaipur',
# ...

# %%
location =[]
for i in soup.find_all('div',class_="restnt-loc ellipsis"):
    location.append(i.text)
location
# Out:
# ['Nirwana Hometel,Bani Park, Central Jaipur',
#  'Bani Park, Central Jaipur',
#  'Hotel Park Prime,C Scheme, Central Jaipur',
#  'C Scheme, Central Jaipur',
#  'Golden Tulip,Mirza Ismail Road, West Jaipur',
#  'Lemon Tree Premier Hotel,Bani Park, Central Jaipur',
#  'Lemon Tree Premier Hotel,Bani Park, Central Jaipur',
#  'Zone by The Park,Bani Park, Central Jaipur',
#  'Lal Kothi, Central Jaipur',
#  'Vaishali Nagar, West Jaipur',
#  'Renest,Mansarovar, South Jaipur',
#  'Adarsh Nagar, East Jaipur',
#  'Red Fox Hotel,Malviya Nagar, South Jaipur',
#  'Lords Plaza,Tonk Road, South Jaipur',
#  'Malviya Nagar, South Jaipur',
#  'Malviya Nagar, South Jaipur',
#  'Hotel Clarks Amer,Malviya Nagar, South Jaipur',
#  'Tonk Road, South Jaipur',
#  'The Lalit Jaipur,Jagatpura, South Jaipur',
#  'Intercontinental Jaipur,Tonk Road, South Jaipur',
#  'Mansarovar, South Jaipur']

# %%
price =[]
for i in soup.find_all("span",class_="double-line-ellipsis"):
    price.append(i.text.replace('₹',''))
price
# Out:
# [' 1,200 for 2 (approx) | Chinese, North Indian, Fast Food',
#  ' 1,000 for 2 (approx) | North Indian, Rajasthani, Desserts, Beverages',
#  ' 1,500 for 2 (approx) | Chinese, North Indian, Continental',
#  ' 1,400 for 2 (approx) | Continental, North Indian, Chinese, Fast Food',
#  ' 2,000 for 2 (approx) | Chinese, North Indian, Fusion, Rajasthani, Fast Food',
#  ' 1,500 for 2 (approx) | Asian, Chinese',
#  ' 1,600 for 2 (approx) | North Indian, Continental, Italian, Rajasthani, Chinese',
#  ' 2,000 for 2 (approx) | Chinese, North Indian, Thai',
#  ' 800 for 2 (approx) | Fast Food, North Indian',
#  ' 1,200 for 2 (approx) | North Indian, Chinese, Rajasthani, Desserts, Beverages',
#  ' 1,100 for 2 (approx) | North Indian, Asian, Rajasthani',
#  ' 1,500 for 2 (approx) | North Indian, Chinese, Asian, Continental',
#  ' 1,300 for 2 (approx) | Mughlai, North Indian, Continental',
#  ' 1,000 for 2 (approx) | North Indian, Chinese, Continental',
# ...

# %%
images = []
for i in soup.find_all("img",class_="no-img"):
    images.append(i['data-src'])
images
# Out:
# ['https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/m/f/p51402-15514265815c78e415433e6.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/4/a/i/p49995-169034894864c0ad94ba39d.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/6/m/l/p6351-15638707205d36c600b64b8.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/4/p/t/p49980-164060212161c99a09a3c60.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/a/f/p53559-15719923575db2b3257205b.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/1/x/p/p14756-1652172137627a2569b4d7e.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/c/z/p5784-163904151361b1c9e9b139e.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/u/z/p59294-15615760345d13c26216fea.jpg?tr=tr:n-medium',
# ...

# %%
print(len(titles),len(location),len(price),len(images))
# Out:
# 21 21 21 21

# %%
import pandas as pd
df = pd.DataFrame({'Titles':titles,'Location':location,'Price':price,'Images':images})
df
# Out:
#                                                Titles  \
# 0   Flavours - Cafe RestaurantNirwana Hometel,Bani...
# 1   Rajasthani Thali Dal Baati ChurmaBani Park, Ce...
# 2      OasisHotel Park Prime,C Scheme, Central Jaipur
# 3       Ten Twisters BarbequeC Scheme, Central Jaipur
# 4   MarigoldGolden Tulip,Mirza Ismail Road, West J...
# 5   Republic Of NoodlesLemon Tree Premier Hotel,Ba...
# 6   Citrus CafeLemon Tree Premier Hotel,Bani Park,...
# 7    BazaarZone by The Park,Bani Park, Central Jaipur
# 8              Fusion RestroLal Kothi, Central Jaipur
# 9   TGIB : The Grand Indian BuffetVaishali Nagar, ...
# 10               TribeRenest,Mansarovar, South Jaipur
# 11           Vintage JourneyAdarsh Nagar, East Jaipur
# 12  Clever Fox CafeRed Fox Hotel,Malviya Nagar, So...
# 13  Blue CorianderLords Plaza,Tonk Road, South Jaipur
# 14    The Barbeque CompanyMalviya Nagar, South Jaipur
# 15  TVG - The Vegetarian GrillMalviya Nagar, South...
# ...
